# %%
import sys
sys.path.append('E:/github/EL2.0')
from geeservice.utils import get_filtered_info,fliter_img_id
from IPython.display import HTML
cid = 'COPERNICUS/S2_SR_HARMONIZED'
img_ids = fliter_img_id(cid,start_date='2023-01-01',end_date='2023-06-30',bounds=['湖北省','武汉市'])
info = get_filtered_info(cid,info_type='getinfo')
print(len(img_ids))

display(info)
# Out:
# 339
# {'bands': [],
#  'features': [{'bands': [{'crs': 'EPSG:32649',
#      'crs_transform': [60, 0, 699960, 0, -60, 3400020],
#      'data_type': {'max': 65535,
#       'min': 0,
#       'precision': 'int',
#       'type': 'PixelType'},
#      'dimensions': [1830, 1830],
#      'id': 'B1'},
#     {'crs': 'EPSG:32649',
#      'crs_transform': [10, 0, 699960, 0, -10, 3400020],
#      'data_type': {'max': 65535,
#       'min': 0,
#       'precision': 'int',
#       'type': 'PixelType'},
#      'dimensions': [10980, 10980],
#      'id': 'B2'},
#     {'crs': 'EPSG:32649',
#      'crs_transform': [10, 0, 699960, 0, -10, 3400020],
#      'data_type': {'max': 65535,
#       'min': 0,
#       'precision': 'int',
#       'type': 'PixelType'},
#      'dimensions': [10980, 10980],
#      'id': 'B3'},
#     {'crs': 'EPSG:32649',
#      'crs_transform': [10, 0, 699960, 0, -10, 3400020],
#      'data_type': {'max': 65535,
#       'min': 0,
#       'precision': 'int',
#       'type': 'PixelType'},
# ...
